# %% [markdown]
# # SolarCast AI - Training Notebook
#
# This notebook is designed to train the **LSTM** and **LSTM-Attention** models for solar irradiance forecasting using the NSRDB dataset.
#
# ### 🚀 Setup Instructions:
# 1. Ensure you have selected a **GPU Runtime** (`Runtime` -> `Change runtime type` -> `T4 GPU`).
# 2. Run the cells below to clone the repository and start training.

# %%
# 1. Clone the Repository
# !git clone https://github.com/sakalesha/Solar-Cast-AI.git
# %cd Solar-Cast-AI

# %%
# 2. Environment Verification
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# %%
# 3. Run Training Pipeline
# This will iterate through LA, Bengaluru, Delhi, and Chennai for both Baseline and Attention models.
# !python -m src.train

# %%
# 4. View Results
import pandas as pd
results = pd.read_csv('results.csv')
display(results)

# %% [markdown]
# ### 📂 Saving Models to Google Drive (Optional)
# If you want to persist the trained models to your Drive, run the cell below:

# %%
from google.colab import drive
import shutil
import os

drive.mount('/content/drive')

# Define your drive path
drive_path = '/content/drive/MyDrive/SolarCast_Models/'
if not os.path.exists(drive_path):
    os.makedirs(drive_path)

# Copy models and results
# !cp -r models/* {drive_path}
# !cp results.csv {drive_path}

print(f"Models and results backed up to {drive_path}")
